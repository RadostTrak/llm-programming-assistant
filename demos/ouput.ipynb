# %% [markdown]
# outline='Outline for a beginner-friendly tutorial: Modulo operator in Python
#
#
# Topic overview \n Learn what the modulo operator (%) does in Python.\n- See simple examples and learn how it works with whole numbers and decimal numbers.\n- Understand how Python decides the sign of the result and why that matters.\n- Explore common uses and a few gotchas to avoid mistakes.\n\nPrerequisites\n- Basic arithmetic (addition, subtraction, multiplication, division).\n- Very little or no prior programming experience.\n\n1) What is modulo?\n- Definition: modulo gives the remainder after division.\n- In Python, the operator is the percent sign: a % b means the remainder when a is divided by b.\n- Simple example: 7 % 3 = 1 (7 divided by 3 leaves a remainder of 1).\n\n2) How to write it in Python\n- Syntax: a % b\n- Examples to try:\n  - 10 % 3  -> 1\n  - 9 % 5   -> 4\n  - 14 % 7  -> 0\n- Types you can use: integers and floating-point numbers (floats).\n\n3) How Python decides the sign of the result\n- Rule: the sign of the result is the same as the sign of the divisor (the second number, b).\n- Examples:\n  - 10 % 3   = 1  (positive divisor, positive result)\n  - -10 % 3  = 2  (negative dividend, positive divisor)\n  - 10 % -3  = -2  (positive dividend, negative divisor)\n  - -10 % -3 = -1  (both negative, result negative)\n- Quick intuition: Python finds a multiple of the divisor that is closest to the dividend without going over, then returns what’s left over.\n\n4) Modulo with floating-point numbers\n- You can use the operator with floats:\n  - 5.5 % 2 = 1.5\n  - -5.5 % 2 = 0.5\n- Important relationship:\n  - a % b = a - b * floor(a / b)\n- Note: with floats, be mindful of tiny rounding errors. If you need a different kind of remainder (C-style), there are other functions in math (see tip section).\n\n5) How modulo relates to floor division\n- Floor division in Python uses // and rounds toward negative infinity.\n- Relationship: a == (a // b) * b + (a % b)\n- Examples:\n  - 10 // 3 = 3; 3 * 3 = 9; 10 % 3 = 1; 9 + 1 = 10\n  - -10 // 3 = -4; -4 * 3 = -12; -10 % 3 = 2; -12 + 2 = -10\n- This helps understand why the sign rules look the way they do.\n\n6) Common uses of modulo\n- Circular indexing: wrap around a list or array length n.\n  - index = i % n\n- Check for even/odd: i % 2 == 0 means even, i % 2 == 1 means odd.\n- Step-wise time calculations (minutes, seconds) where you wrap around after reaching a limit.\n\n7) Things to be careful about\n- Division by zero: a % 0 will raise an error.\n- Modulo with complex numbers: not supported in Python (will raise an error).\n- Floating-point precision: tiny errors can appear, which may affect equality checks.\n- If you need C-style remainder for floats (truncation toward zero), look at math.fmod (explained below).\n\n8) Quick reference and tips\n- Basic form: a % b\n- Check for zero divisor first to avoid errors.\n- To convert a result to a positive remainder regardless of signs, you can adjust logic, but the default Python rule is as described above.\n- If you’re working with floats and you need a different kind of remainder, consider math.fmod(a, b) (note the difference in how it computes remainder).\n\n9) Quick exercises\n- Practice 1: What is 25 % 4?\n- Practice 2: What is -25 % 4? (explain why the result is what it is)\n- Practice 3: What is 7.5 % 2? What is 7.5 // 2?\n- Practice 4: Use modulo to wrap an index: you have a list of 8 items; how do you access the item for a given number i using modulo?\n\n10) Summary\n- The modulo operator gives a remainder after division.\n- The sign of the result follows the divisor.\n- It works with integers and floats, with specific rules for each.\n- It pairs with floor division to show a neat equation: a = (a // b) * b + (a % b).\n\nOptional extensions\n- Explore how modulo interacts with negative numbers more by trying different examples.\n- Look at how modulo is used in problems like finding the day of the week for a given number of days from today.\n- Compare Python’s modulo with other languages to see how the rules differ.\n' tutorial='Tutorial content will be generated from the above outline. It will include beginner-friendly explanations, clear examples, and small hands-on exercises to reinforce learning.'
