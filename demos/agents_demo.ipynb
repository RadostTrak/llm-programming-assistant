# %%
from agents import Agent, Runner
agent = Agent(
    name = 'Basic Agent',
    instructions = 'You are a greeter bot. Greet the user with their name.'
)

result = await Runner.run(agent, 'Hello, my name is Radost. How are you?')
result.final_output
# Out:
# "Hello, Radost! I'm here and ready to help you. How can I assist you today?"
